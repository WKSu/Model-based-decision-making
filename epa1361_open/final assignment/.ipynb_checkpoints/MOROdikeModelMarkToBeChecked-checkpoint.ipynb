# %%
import time

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from ema_workbench import (Model, CategoricalParameter, Policy, ema_logging,
                           ScalarOutcome, IntegerParameter, RealParameter, 
                           Scenario, MultiprocessingEvaluator)

from dike_model_function import *
from dike_model_optimization import *
from problem_formulation import *

from ema_workbench.em_framework.optimization import (HyperVolume, 
                                                     EpsilonProgress)
from ema_workbench.analysis import prim

ema_logging.log_to_stderr(ema_logging.INFO);

# %%
function = DikeNetwork()
# workbench model:
dike_model = Model('dikesnet', function=function)

# Uncertainties and Levers:
# Specify uncertainties range:
Real_uncert = {'Bmax': [30, 350], 'pfail': [0, 1]}  # m and [.]
# breach growth rate [m/day]
cat_uncert_loc = {'Brate': (0.9, 1.5, 1000)}

cat_uncert = {'discount rate': (1.5, 2.5, 3.5, 4.5)}
Int_uncert = {'A.0_ID flood wave shape': [0, 132]}

# Range of dike heightening:
dike_lev = {'DikeIncrease': [0,10]}     # dm

# Series of five Room for the River projects:
rfr_lev = ['{}_RfR'.format(project_id) for project_id in range(0, 5)]

# Time of warning: 0, 1, 2, 3, 4 days ahead from the flood
EWS_lev = {'EWS_DaysToThreat': [0, 3]}  # days

uncertainties = []
levers = []

for dike in function.dikelist:
    # uncertainties in the form: locationName_uncertaintyName
    for uncert_name in Real_uncert.keys():
        name = "{}_{}".format(dike, uncert_name)
        lower, upper = Real_uncert[uncert_name]
        uncertainties.append(RealParameter(name, lower, upper))

    for uncert_name in cat_uncert_loc.keys():
        name = "{}_{}".format(dike, uncert_name)
        categories = cat_uncert_loc[uncert_name]
        uncertainties.append(CategoricalParameter(name, categories))

    # location-related levers in the form: locationName_leversName
    for lev_name in dike_lev.keys():
        name = "{}_{}".format(dike, lev_name)
        levers.append(IntegerParameter(name, dike_lev[lev_name][0],
                                       dike_lev[lev_name][1]))

for uncert_name in cat_uncert.keys():
    categories = cat_uncert[uncert_name]
    uncertainties.append(CategoricalParameter(uncert_name, categories))

# project-related levers can be either 0 (not implemented) or 1
# (implemented)
for uncert_name in Int_uncert.keys():
    uncertainties.append(IntegerParameter(uncert_name, Int_uncert[uncert_name][0],
                                          Int_uncert[uncert_name][1]))
    
# RfR levers can be either 0 (not implemented) or 1 (implemented)
for lev_name in rfr_lev:
    levers.append(IntegerParameter(lev_name, 0, 1))

# Early Warning System lever
for lev_name in EWS_lev.keys():
    levers.append(IntegerParameter(lev_name, EWS_lev[lev_name][0],
                                   EWS_lev[lev_name][1]))

# load uncertainties and levers in dike_model:
dike_model.uncertainties = uncertainties
dike_model.levers = levers

# Problem formulations:
# Outcomes are all costs, thus they have to minimized:
direction = ScalarOutcome.MINIMIZE

# 7 Objectives
dikes_variable_names = []
dikes_variable_names.extend(['{}_{}'.format(dike, e) for e in ['Expected Annual Damage', 'Dike Investment Costs']])
dikes_variable_names.extend(['RfR Total Costs'])
dikes_variable_names.extend(['Expected Evacuation Costs'])
        
dike_model.outcomes = [
                        ScalarOutcome('Expected Number of Deaths',
                                      variable_name=['{}_Expected Number of Deaths'.format(dike)
                                                     for dike in function.dikelist],
                                      function=sum_over, kind=direction),
    
                        ScalarOutcome('Expected Annual Damage',
                                      variable_name=['{}_Expected Annual Damage'.format(dike)
                                                     for dike in function.dikelist],
                                      function=sum_over, kind=direction),

                        ScalarOutcome('Total Dike Investment Costs',
                                      variable_name=['{}_Dike Investment Costs'.format(dike)
                                                     for dike in function.dikelist],
                                      function=sum_over, kind=direction),

                        ScalarOutcome('Expected Evacuation Costs',  kind=direction),

                        ScalarOutcome('RfR Total Costs', kind=direction),
    
                        ScalarOutcome('Total Construction Costs', 
                                        variable_name=['{}_Dike Investment Costs'.format(dike) 
                                         for dike in function.dikelist] + ['RfR Total Costs'
                                             ] + ['Expected Evacuation Costs'],
                                        function=sum_over, kind=direction)]
                        
#                         ScalarOutcome('All Costs',
#                                        variable_name=[var for var in dikes_variable_names], 
#                                        function=sum_over, kind=direction)]

# # 17 Objectives
# outcomes = []

# for dike in function.dikelist:
#     for entry in ['Expected Annual Damage', 'Dike Investment Costs',
#                   'Expected Number of Deaths']:
#         o = ScalarOutcome('{}_{}'.format(dike, entry), kind=direction)
#         outcomes.append(o)

# outcomes.append(ScalarOutcome('RfR Total Costs', kind=direction))
# outcomes.append(ScalarOutcome('Expected Evacuation Costs', kind=direction))
        
# dike_model.outcomes = outcomes
# Out:
# [MainProcess/INFO] model initialized

# %%
from ema_workbench import ema_logging, MultiprocessingEvaluator

ema_logging.log_to_stderr(ema_logging.INFO)

with MultiprocessingEvaluator(dike_model) as evaluator:
    results = evaluator.perform_experiments(scenarios=500,
                                            policies=3,
                                            uncertainty_sampling='mc')
# Out:
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 500 scenarios * 3 policies * 1 model(s) = 1500 experiments
# [MainProcess/INFO] 150 cases completed
# [MainProcess/INFO] 300 cases completed
# [MainProcess/INFO] 450 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 750 cases completed
# [MainProcess/INFO] 900 cases completed
# [MainProcess/INFO] 1050 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1350 cases completed
# [MainProcess/INFO] 1500 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool

# %%
import functools

def robustness(direction, threshold, data):
    if direction == SMALLER:
        return np.sum(data<=threshold)/data.shape[0]
    else:
        return np.sum(data>=threshold)/data.shape[0]

SMALLER = 'SMALLER'
LARGER = 'LARGER'

ExpectedNumberofDeaths = functools.partial(robustness, SMALLER, 0.001)
ExpectedAnnualDamage = functools.partial(robustness, SMALLER, 100000)
TotalDikeInvestmentCosts = functools.partial(robustness, SMALLER, 2300000000)
ExpectedEvacuationCosts = functools.partial(robustness, SMALLER, 2300000000)
# RfRTotalCosts = functools.partial(robustness, SMALLER, 2300000000)
RfRTotalCosts = functools.partial(robustness, SMALLER, 1.5e9)
TotalConstructionCosts = functools.partial(robustness, SMALLER, 2.3e9)

# %%
fig, axes = plt.subplots(ncols=3, nrows=2, figsize=(12,12),
                         sharex=True)
axes = [axes[0,0],axes[0,1],axes[1,0],axes[1,1],axes[1,2],axes[0,2]]

robustness_funcs = {"Expected Number of Deaths": ExpectedNumberofDeaths,
                    "Expected Annual Damage": ExpectedAnnualDamage,
                    "Total Dike Investment Costs": TotalDikeInvestmentCosts,
                    "Expected Evacuation Costs": ExpectedEvacuationCosts,
                    "RfR Total Costs": RfRTotalCosts,
                    "Total Construction Costs": TotalConstructionCosts}

experiments, outcomes = results

for ax, (outcome, value) in zip(axes, outcomes.items()):
    for policy in np.unique(experiments['policy']):
        logical = experiments['policy'] == policy
        data = value[logical]
        
        robustness = []
        # data.shape should be (500,), given n_scenarios=500
        for i in range(1, data.shape[0]):
            robustness.append(robustness_funcs[outcome](data[0:i]))
        ax.plot(robustness, label=policy)
    ax.set_xlabel("# experiments")
    ax.set_ylabel(outcome)
    
plt.show()

# %%
from ema_workbench.em_framework import sample_uncertainties
n_scenarios =16
scenarios = sample_uncertainties(dike_model, n_scenarios)
nfe = int(12000)

# %%
MAXIMIZE = ScalarOutcome.MAXIMIZE
MINIMIZE = ScalarOutcome.MINIMIZE

robustnes_functions = [ScalarOutcome('fraction Expected Number of Deaths', kind=MINIMIZE, 
                             variable_name='Expected Number of Deaths', function=ExpectedNumberofDeaths),
                       ScalarOutcome('fraction Expected Annual Damage', kind=MINIMIZE, 
                             variable_name='Expected Annual Damage', function=ExpectedAnnualDamage),
                       ScalarOutcome('fraction Total Dike Investment Costs', kind=MINIMIZE, 
                             variable_name='Total Dike Investment Costs', function=TotalDikeInvestmentCosts),
                       ScalarOutcome('fraction Expected Evacuation Costs', kind=MINIMIZE, 
                             variable_name='Expected Evacuation Costs', function=ExpectedEvacuationCosts),
                       ScalarOutcome('fraction RfR Total Costs', kind=MINIMIZE, 
                             variable_name='RfR Total Costs', function=RfRTotalCosts),
                       ScalarOutcome('fraction TotalConstructionCosts', kind=MINIMIZE, 
                             variable_name='Total Construction Costs', function=TotalConstructionCosts)]

# %%
from ema_workbench import (MultiprocessingEvaluator, ema_logging, 
                           perform_experiments, SequentialEvaluator)
from ema_workbench.em_framework.optimization import HyperVolume
from ema_workbench.em_framework.optimization import EpsilonProgress
from ema_workbench.em_framework.evaluators import BaseEvaluator

# requires master branch of workbench
# enables us to avoid logging to many intermediate results
# can be ignored without invalidating results
BaseEvaluator.reporting_frequency = 0.1

ema_logging.log_to_stderr(ema_logging.INFO)

convergence = [HyperVolume(minimum=[0,0,0,0,0,0], maximum=[1, 1, 1, 1, 1, 1]),
               EpsilonProgress()]

start = time.time()

with MultiprocessingEvaluator(dike_model) as evaluator:
    archive, convergence = evaluator.robust_optimize(robustnes_functions, scenarios, 
                                               nfe=nfe, convergence=convergence,
                                               epsilons=[0.05,]*len(robustnes_functions))
end = time.time()
print('Processing time :',(end - start)/60, 'Minutes')
# Out:
# [MainProcess/INFO] pool started
# [MainProcess/INFO] generation 0: 0/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 1: 100/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 2: 200/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 3: 300/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 4: 400/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 5: 500/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 6: 600/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 7: 700/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 8: 800/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 9: 899/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 98 policies * 1 model(s) = 1568 experiments
# [MainProcess/INFO] 523 cases completed
# [MainProcess/INFO] 1046 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 10: 997/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 11: 1097/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 12: 1197/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 97 policies * 1 model(s) = 1552 experiments
# [MainProcess/INFO] 517 cases completed
# [MainProcess/INFO] 1034 cases completed
# [MainProcess/INFO] 1551 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 13: 1294/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 14: 1394/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 15: 1494/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 16: 1594/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 17: 1694/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 18: 1794/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 96 policies * 1 model(s) = 1536 experiments
# [MainProcess/INFO] 512 cases completed
# [MainProcess/INFO] 1024 cases completed
# [MainProcess/INFO] 1536 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 19: 1890/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 20: 1989/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 97 policies * 1 model(s) = 1552 experiments
# [MainProcess/INFO] 517 cases completed
# [MainProcess/INFO] 1034 cases completed
# [MainProcess/INFO] 1551 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 21: 2086/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 22: 2185/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 98 policies * 1 model(s) = 1568 experiments
# [MainProcess/INFO] 523 cases completed
# [MainProcess/INFO] 1046 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 23: 2283/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 24: 2382/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 25: 2482/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 26: 2582/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 27: 2682/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 28: 2782/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 98 policies * 1 model(s) = 1568 experiments
# [MainProcess/INFO] 523 cases completed
# [MainProcess/INFO] 1046 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 29: 2880/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 30: 2980/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 31: 3080/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 32: 3179/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 33: 3278/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 34: 3378/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 35: 3477/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 36: 3577/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 37: 3677/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 38: 3776/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 97 policies * 1 model(s) = 1552 experiments
# [MainProcess/INFO] 517 cases completed
# [MainProcess/INFO] 1034 cases completed
# [MainProcess/INFO] 1551 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 39: 3873/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 40: 3973/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 41: 4072/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 42: 4172/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 43: 4272/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 44: 4371/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 45: 4471/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 97 policies * 1 model(s) = 1552 experiments
# [MainProcess/INFO] 517 cases completed
# [MainProcess/INFO] 1034 cases completed
# [MainProcess/INFO] 1551 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 46: 4568/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 47: 4668/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 48: 4767/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 98 policies * 1 model(s) = 1568 experiments
# [MainProcess/INFO] 523 cases completed
# [MainProcess/INFO] 1046 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 49: 4865/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 50: 4964/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 51: 5064/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 97 policies * 1 model(s) = 1552 experiments
# [MainProcess/INFO] 517 cases completed
# [MainProcess/INFO] 1034 cases completed
# [MainProcess/INFO] 1551 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 52: 5161/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 53: 5261/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 54: 5361/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 55: 5461/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 56: 5561/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 57: 5661/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 58: 5760/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 59: 5860/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 60: 5959/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 94 policies * 1 model(s) = 1504 experiments
# [MainProcess/INFO] 501 cases completed
# [MainProcess/INFO] 1002 cases completed
# [MainProcess/INFO] 1503 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 61: 6053/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 62: 6152/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 63: 6252/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 64: 6351/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 65: 6451/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 66: 6551/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 67: 6651/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 68: 6750/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 98 policies * 1 model(s) = 1568 experiments
# [MainProcess/INFO] 523 cases completed
# [MainProcess/INFO] 1046 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 69: 6848/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 70: 6948/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 71: 7048/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 72: 7148/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 73: 7247/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 74: 7347/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 75: 7447/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 76: 7546/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 98 policies * 1 model(s) = 1568 experiments
# [MainProcess/INFO] 523 cases completed
# [MainProcess/INFO] 1046 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 77: 7644/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 78: 7744/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 79: 7843/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 80: 7943/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 81: 8042/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 82: 8142/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 98 policies * 1 model(s) = 1568 experiments
# [MainProcess/INFO] 523 cases completed
# [MainProcess/INFO] 1046 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 83: 8240/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 96 policies * 1 model(s) = 1536 experiments
# [MainProcess/INFO] 512 cases completed
# [MainProcess/INFO] 1024 cases completed
# [MainProcess/INFO] 1536 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 84: 8336/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 98 policies * 1 model(s) = 1568 experiments
# [MainProcess/INFO] 523 cases completed
# [MainProcess/INFO] 1046 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 85: 8434/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 97 policies * 1 model(s) = 1552 experiments
# [MainProcess/INFO] 517 cases completed
# [MainProcess/INFO] 1034 cases completed
# [MainProcess/INFO] 1551 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 86: 8531/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 87: 8631/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 88: 8730/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 98 policies * 1 model(s) = 1568 experiments
# [MainProcess/INFO] 523 cases completed
# [MainProcess/INFO] 1046 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 89: 8828/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 98 policies * 1 model(s) = 1568 experiments
# [MainProcess/INFO] 523 cases completed
# [MainProcess/INFO] 1046 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 90: 8926/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 97 policies * 1 model(s) = 1552 experiments
# [MainProcess/INFO] 517 cases completed
# [MainProcess/INFO] 1034 cases completed
# [MainProcess/INFO] 1551 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 91: 9023/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 92: 9123/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 93: 9223/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 94: 9323/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 95: 9423/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 96: 9523/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 97: 9623/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 98 policies * 1 model(s) = 1568 experiments
# [MainProcess/INFO] 523 cases completed
# [MainProcess/INFO] 1046 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 98: 9721/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 99: 9820/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 98 policies * 1 model(s) = 1568 experiments
# [MainProcess/INFO] 523 cases completed
# [MainProcess/INFO] 1046 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 100: 9918/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 101: 10018/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 96 policies * 1 model(s) = 1536 experiments
# [MainProcess/INFO] 512 cases completed
# [MainProcess/INFO] 1024 cases completed
# [MainProcess/INFO] 1536 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 102: 10114/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 103: 10214/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 104: 10314/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 96 policies * 1 model(s) = 1536 experiments
# [MainProcess/INFO] 512 cases completed
# [MainProcess/INFO] 1024 cases completed
# [MainProcess/INFO] 1536 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 105: 10410/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 106: 10510/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 107: 10609/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 108: 10709/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 109: 10809/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 110: 10908/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 98 policies * 1 model(s) = 1568 experiments
# [MainProcess/INFO] 523 cases completed
# [MainProcess/INFO] 1046 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 111: 11006/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 112: 11106/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 113: 11205/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 97 policies * 1 model(s) = 1552 experiments
# [MainProcess/INFO] 517 cases completed
# [MainProcess/INFO] 1034 cases completed
# [MainProcess/INFO] 1551 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 114: 11302/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 115: 11402/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 116: 11502/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 98 policies * 1 model(s) = 1568 experiments
# [MainProcess/INFO] 523 cases completed
# [MainProcess/INFO] 1046 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 117: 11600/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 118: 11699/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 119: 11798/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 100 policies * 1 model(s) = 1600 experiments
# [MainProcess/INFO] 533 cases completed
# [MainProcess/INFO] 1066 cases completed
# [MainProcess/INFO] 1599 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 120: 11898/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] generation 121: 11997/12000 nfe
# [MainProcess/INFO] performing 16 scenarios * 99 policies * 1 model(s) = 1584 experiments
# [MainProcess/INFO] 528 cases completed
# [MainProcess/INFO] 1056 cases completed
# [MainProcess/INFO] 1584 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] optimization completed, found 1 solutions
# [MainProcess/INFO] terminating pool
# Processing time : 984.8516729076704 Minutes

# %%
convergence.to_csv("convergence.csv")
archive.to_csv("MOROresult.csv")

# %%
#from platypus import NSGAII, Problem, Real

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharex=True, figsize=(8,4))
ax1.plot(convergence.nfe, convergence.epsilon_progress)
ax1.set_ylabel('$\epsilon$-progress')
ax2.plot(convergence.nfe, convergence.hypervolume)
ax2.set_ylabel('hypervolume')

ax1.set_xlabel('number of function evaluations')
ax2.set_xlabel('number of function evaluations')
plt.show()

# %%
data = archive.loc[:, [o.name for o in robustnes_functions]]
limits = parcoords.get_limits(data)
limits.loc[0, :] = 0
limits.loc[1, :] = 1

paraxes = parcoords.ParallelAxes(limits)
paraxes.plot(data)
plt.show()
