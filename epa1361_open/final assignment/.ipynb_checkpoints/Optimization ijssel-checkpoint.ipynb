# %% [markdown]
# # Optimization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import platypus

# %%
import sys

sys.path.append('./final assignment/')

import dike_model_function
import dike_model_optimization
import dike_model_simulation
import problem_formulation
# Out:
# /Users/jhkwakkel/miniconda3/lib/python3.6/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)

# %%
from ema_workbench import Policy, perform_experiments
from ema_workbench import ema_logging, MultiprocessingEvaluator
import ema_workbench
ema_logging.log_to_stderr(ema_logging.INFO)
# Out:
# <Logger EMA (DEBUG)>

# %%
print(ema_workbench.__version__)
# Out:
# 1.2

# %%
model = problem_formulation.get_model_for_problem_formulation(1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-cadadaa1e3a8> in <module>()
# ----> 1 model = problem_formulation.get_model_for_problem_formulation(1)
#
# ~/Documents/workspace/epa1361_open/final assignment/problem_formulation.py in get_model_for_problem_formulation(problem_formulation_id)
#      23     '''
#      24     # Load the model:
# ---> 25     function = DikeNetwork()
#      26     # workbench model:
#      27     dike_model = Model('dikesnet', function=function)
#
# ~/Documents/workspace/epa1361_open/final assignment/dike_model_function.py in __init__(self)
#      26     def __init__(self):
#      27         # load network
# ---> 28         G, dike_list, dike_branch = funs_generate_network.get_network()
#      29
#      30         # Load hydrological statistics:
#
# ...

# %%
with MultiprocessingEvaluator(model) as evaluator:
    results = evaluator.optimize(nfe=250, searchover='levers',
                                 epsilons=[0.1,]*len(model.outcomes))
# Out:
# [MainProcess/INFO] pool started
# [MainProcess/INFO] generation 0: 0/250 nfe
# [MainProcess/INFO] performing 1 scenarios * 100 policies * 1 model(s) = 100 experiments
# [SpawnPoolWorker-1/ERROR] 'ID flood wave shape'
# Traceback (most recent call last):
#   File "C:\Anaconda\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Anaconda\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Anaconda\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Anaconda\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Anaconda\lib\site-packages\ema_workbench\em_framework\model.py", line 442, in run_experiment
#     model_output = self.function(**experiment)
# ...

# %%
results
